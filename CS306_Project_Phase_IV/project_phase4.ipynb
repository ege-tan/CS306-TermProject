# %%
# !python -m pip install "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (670 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.0/670.0 kB 2.5 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 18.0 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.7.2

# %%
from pymongo import MongoClient

def connectDB():
    # Replace the connection string with your MongoDB connection string
    # You can obtain the connection string from your MongoDB Atlas dashboard or configure it locally
    # For example, if your database is running on localhost, the connection string might look like this:
    # "mongodb://localhost:27017/"

    connection_string = "mongodb+srv://admin:admin@phase4.4gndiul.mongodb.net/?retryWrites=true&w=majority&appName=phase4"
    client = MongoClient(connection_string)

    # Access a specific database (replace "your_database_name" with your actual database name)
    db = client.phase4
    print("Connection established to your db")
    return db

# %%
from pymongo import errors

def create_collection(db, collection_name):
    try:
        if collection_name not in db.list_collection_names():
            db.create_collection(collection_name)
            print(f"Collection '{collection_name}' created.")
        elif collection_name in db.list_collection_names():
            print("Collection already exists")
    except Exception as e:
        print("An error occurred: ", e)

def insert_data(db, collection_name, data):
    try:
        collection = db[collection_name]
        existing_entry = collection.find_one({"id": data["id"]})
        if existing_entry:
            print(f"An entry with ID '{data['id']}' already exists.")
        else:
            collection.insert_one(data)
            print("Data inserted successfully!")
    except errors.PyMongoError as e:
        print(f"An error occurred while inserting data: {e}")

def read_all_data(db, collection_name):
    try:
        collection = db[collection_name]
        for document in collection.find():
            print(document)
    except errors.PyMongoError as e:
        print(f"An error occurred while reading data: {e}")

def read_filtered_data(db, collection_name, value):
    try:
        collection = db[collection_name]
        filter_criteria = {"given_star": {"$gt": value}}
        documents = collection.find(filter_criteria)
        results = list(documents)
        if results:
            for document in results:
                print(document)
        else:
            print("No documents found with the given filter.")
        return results
    except errors.PyMongoError as e:
        print(f"An error occurred while reading data: {e}")
        return []

def update_data(db, collection_name, entry_id, update):
    try:
        collection = db[collection_name]
        existing_entry = collection.find_one({"id": entry_id})
        if not existing_entry:
            print(f"No entry found with ID '{entry_id}'.")
        else:
            collection.update_one({"id": entry_id}, {"$set": update})
            print("Data updated successfully!")
    except errors.PyMongoError as e:
        print(f"An error occurred while updating data: {e}")

def delete_data(db, collection_name, entry_id):
    try:
        collection = db[collection_name]
        existing_entry = collection.find_one({"id": entry_id})
        if not existing_entry:
            print(f"No entry found with ID '{entry_id}'.")
        else:
            collection.delete_one({"id": entry_id})
            print("Data deleted successfully!")
    except errors.PyMongoError as e:
        print(f"An error occurred while deleting data: {e}")

def list_collections(db):
    collections = db.list_collection_names()
    for i, collection in enumerate(collections, start=1):
        print(f"{i} - {collection}")
    return collections

def main():
    db = connectDB()

    while True:
        print("\nPlease select an operation:")
        print("1 - Create collection")
        print("2 - Read all data in a collection")
        print("3 - Read some part of the data while filtering")
        print("4 - Insert data")
        print("5 - Delete data")
        print("6 - Update data")
        print("7 - Exit")

        choice = input("Your choice: ")

        if choice == "1":
            collection_name = input("Name of the collection to create: ")
            create_collection(db, collection_name)
        elif choice == "2":
            print("Please select the collection you want to read data from:")
            collections = list_collections(db)
            collection_choice = int(input("Selected option: ")) - 1
            if 0 <= collection_choice < len(collections):
                collection_name = collections[collection_choice]
                read_all_data(db, collection_name)
            else:
                print("Invalid selection.")
        elif choice == "3":
            print("Please select the collection you want to read data from:")
            collections = list_collections(db)
            collection_choice = int(input("Selected option: ")) - 1
            if 0 <= collection_choice < len(collections):
                collection_name = collections[collection_choice]
                value = int(input("Filter acc to 'given_star' (greater than): "))
                read_filtered_data(db, collection_name, value)
            else:
                print("Invalid selection.")
        elif choice == "4":
            print("Please select the collection you want to insert data into:")
            collections = list_collections(db)
            collection_choice = int(input("Selected option: ")) - 1
            if 0 <= collection_choice < len(collections):
                collection_name = collections[collection_choice]
                entry_id = input("Enter ID for the entry: ")  # Ask user for ID
                name = input("Name: ")
                review_message = input("Review message: ")
                given_star = int(input("Given star (out of 5): "))
                data = {
                    "id": entry_id,
                    "name": name,
                    "review_message": review_message,
                    "given_star": given_star
                }
                insert_data(db, collection_name, data)
            else:
                print("Invalid selection.")
        elif choice == "5":
            print("Please select the collection you want to delete data from:")
            collections = list_collections(db)
            collection_choice = int(input("Selected option: ")) - 1
            if 0 <= collection_choice < len(collections):
                collection_name = collections[collection_choice]
                entry_id = input("Enter ID of the record to delete: ")
                delete_data(db, collection_name, entry_id)
            else:
                print("Invalid selection.")
        elif choice == "6":
            print("Please select the collection you want to update data in:")
            collections = list_collections(db)
            collection_choice = int(input("Selected option: ")) - 1
            if 0 <= collection_choice < len(collections):
                collection_name = collections[collection_choice]
                entry_id = input("Enter ID of the record to update: ")
                update_field = input("Field to update: ")
                update_value = input("New value: ")
                update_data(db, collection_name, entry_id, {update_field: update_value})
            else:
                print("Invalid selection.")
        elif choice == "7":
            print("Exiting...")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Connection established to your db
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 1
# Name of the collection to create: student_evaluation
# Collection 'student_evaluation' created.
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 1
# Name of the collection to create: teacher_evaluation
# Collection 'teacher_evaluation' created.
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 4
# Please select the collection you want to insert data into:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID for the entry: 1
# Name: Ege Tan
# Review message: good , student , hardworking student
# Given star (out of 5): 5
# Data inserted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 4
# Please select the collection you want to insert data into:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID for the entry: 2
# Name: Efe Sözer
# Review message: good , student , hardworking student
# Given star (out of 5): 5
# Data inserted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 4
# Please select the collection you want to insert data into:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID for the entry: 3
# Name: Kutluhan Berke Kılıçkaya
# Review message: good , student , hardworking student
# Given star (out of 5): 5
# Data inserted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 4
# Please select the collection you want to insert data into:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID for the entry: 4
# Name: Ahmet Emre
# Review message: bad student, he is not studying
# Given star (out of 5): 1
# Data inserted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 4
# Please select the collection you want to insert data into:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID for the entry: Ahmet Ekrem Rüzgar
# Name: deneme
# Review message: deneme
# Given star (out of 5): 1
# Data inserted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 6
# Please select the collection you want to update data in:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID of the record to update: Ahmet Ekrem Rüzgar
# Field to update: id
# New value: 5
# Data updated successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 2
# Please select the collection you want to read data from:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# {'_id': ObjectId('6659c058568bb4f8d6d27064'), 'id': '1', 'name': 'Ege Tan', 'review_message': 'good , student , hardworking student', 'given_star': 5}
# {'_id': ObjectId('6659c069568bb4f8d6d27065'), 'id': '2', 'name': 'Efe Sözer', 'review_message': 'good , student , hardworking student', 'given_star': 5}
# {'_id': ObjectId('6659c094568bb4f8d6d27066'), 'id': '3', 'name': 'Kutluhan Berke Kılıçkaya', 'review_message': 'good , student , hardworking student', 'given_star': 5}
# {'_id': ObjectId('6659c0c8568bb4f8d6d27067'), 'id': '4', 'name': 'Ahmet Emre', 'review_message': 'bad student, he is not studying', 'given_star': 1}
# {'_id': ObjectId('6659c0fd568bb4f8d6d27068'), 'id': '5', 'name': 'deneme', 'review_message': 'deneme', 'given_star': 1}
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 6
# Please select the collection you want to update data in:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID of the record to update: name
# Field to update: a
# New value: a
# No entry found with ID 'name'.
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 6
# Please select the collection you want to update data in:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID of the record to update: 5
# Field to update: name
# New value: Ahmet Ekrem Rüzgar
# Data updated successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 2
# Please select the collection you want to read data from:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# {'_id': ObjectId('6659c058568bb4f8d6d27064'), 'id': '1', 'name': 'Ege Tan', 'review_message': 'good , student , hardworking student', 'given_star': 5}
# {'_id': ObjectId('6659c069568bb4f8d6d27065'), 'id': '2', 'name': 'Efe Sözer', 'review_message': 'good , student , hardworking student', 'given_star': 5}
# {'_id': ObjectId('6659c094568bb4f8d6d27066'), 'id': '3', 'name': 'Kutluhan Berke Kılıçkaya', 'review_message': 'good , student , hardworking student', 'given_star': 5}
# {'_id': ObjectId('6659c0c8568bb4f8d6d27067'), 'id': '4', 'name': 'Ahmet Emre', 'review_message': 'bad student, he is not studying', 'given_star': 1}
# {'_id': ObjectId('6659c0fd568bb4f8d6d27068'), 'id': '5', 'name': 'Ahmet Ekrem Rüzgar', 'review_message': 'deneme', 'given_star': 1}
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 6
# Please select the collection you want to update data in:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID of the record to update: 5
# Field to update: review_message
# New value: bad student,he is not even studying
# Data updated successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 2
# Please select the collection you want to read data from:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# {'_id': ObjectId('6659c058568bb4f8d6d27064'), 'id': '1', 'name': 'Ege Tan', 'review_message': 'good , student , hardworking student', 'given_star': 5}
# {'_id': ObjectId('6659c069568bb4f8d6d27065'), 'id': '2', 'name': 'Efe Sözer', 'review_message': 'good , student , hardworking student', 'given_star': 5}
# {'_id': ObjectId('6659c094568bb4f8d6d27066'), 'id': '3', 'name': 'Kutluhan Berke Kılıçkaya', 'review_message': 'good , student , hardworking student', 'given_star': 5}
# {'_id': ObjectId('6659c0c8568bb4f8d6d27067'), 'id': '4', 'name': 'Ahmet Emre', 'review_message': 'bad student, he is not studying', 'given_star': 1}
# {'_id': ObjectId('6659c0fd568bb4f8d6d27068'), 'id': '5', 'name': 'Ahmet Ekrem Rüzgar', 'review_message': 'bad student,he is not even studying', 'given_star': 1}
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 4
# Please select the collection you want to insert data into:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# Enter ID for the entry: Yücel Saygın
# Name: Yücel Saygın
# Review message: best teacher in the world
# Given star (out of 5): 5
# Data inserted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 6
# Please select the collection you want to update data in:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# Enter ID of the record to update: Yücel Saygın
# Field to update: id
# New value: 1
# Data updated successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 2
# Please select the collection you want to read data from:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# {'_id': ObjectId('6659c2e5568bb4f8d6d27069'), 'id': '1', 'name': 'Yücel Saygın', 'review_message': 'best teacher in the world', 'given_star': 5}
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 4
# Please select the collection you want to insert data into:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# Enter ID for the entry: 2
# Name: Albert Levi
# Review message: also best teacher in the world
# Given star (out of 5): 5
# Data inserted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 4
# Please select the collection you want to insert data into:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# Enter ID for the entry: 3
# Name: Hasan Ertuğrul Çınar
# Review message: best TA in the world
# Given star (out of 5): 5
# Data inserted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 4
# Please select the collection you want to insert data into:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# Enter ID for the entry: 4
# Name: Kamer Kaya
# Review message: good teacher but , exams are hard
# Given star (out of 5): 2
# Data inserted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 4
# Please select the collection you want to insert data into:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# Enter ID for the entry: 5
# Name: Selim Balcısoy
# Review message: good teacher but , course materials are not sufficient
# Given star (out of 5): 3
# Data inserted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 2
# Please select the collection you want to read data from:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# {'_id': ObjectId('6659c2e5568bb4f8d6d27069'), 'id': '1', 'name': 'Yücel Saygın', 'review_message': 'best teacher in the world', 'given_star': 5}
# {'_id': ObjectId('6659c32e568bb4f8d6d2706a'), 'id': '2', 'name': 'Albert Levi', 'review_message': 'also best teacher in the world', 'given_star': 5}
# {'_id': ObjectId('6659c365568bb4f8d6d2706b'), 'id': '3', 'name': 'Hasan Ertuğrul Çınar', 'review_message': 'best TA in the world', 'given_star': 5}
# {'_id': ObjectId('6659c383568bb4f8d6d2706c'), 'id': '4', 'name': 'Kamer Kaya', 'review_message': 'good teacher but , exams are hard', 'given_star': 2}
# {'_id': ObjectId('6659c3d2568bb4f8d6d2706d'), 'id': '5', 'name': 'Selim Balcısoy', 'review_message': 'good teacher but , course materials are not sufficient', 'given_star': 3}
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 6
# Please select the collection you want to update data in:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID of the record to update: 5
# Field to update: review_message
# New value: he started to work hard , but still not enough
# Data updated successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 6
# Please select the collection you want to update data in:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID of the record to update: 5
# Field to update: given_star
# New value: 3
# Data updated successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 6
# Please select the collection you want to update data in:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# Enter ID of the record to update: 2
# Field to update: review_message
# New value: his exam were reall hard , he asked things that we did not learn
# Data updated successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 6
# Please select the collection you want to update data in:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# Enter ID of the record to update: 2
# Field to update: given_star
# New value: 2
# Data updated successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 5
# Please select the collection you want to delete data from:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Enter ID of the record to delete: 4
# Data deleted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 5
# Please select the collection you want to delete data from:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# Enter ID of the record to delete: 4
# Data deleted successfully!
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 2
# Please select the collection you want to read data from:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# {'_id': ObjectId('6659c2e5568bb4f8d6d27069'), 'id': '1', 'name': 'Yücel Saygın', 'review_message': 'best teacher in the world', 'given_star': 5}
# {'_id': ObjectId('6659c32e568bb4f8d6d2706a'), 'id': '2', 'name': 'Albert Levi', 'review_message': 'his exam were reall hard , he asked things that we did not learn', 'given_star': '2'}
# {'_id': ObjectId('6659c365568bb4f8d6d2706b'), 'id': '3', 'name': 'Hasan Ertuğrul Çınar', 'review_message': 'best TA in the world', 'given_star': 5}
# {'_id': ObjectId('6659c3d2568bb4f8d6d2706d'), 'id': '5', 'name': 'Selim Balcısoy', 'review_message': 'good teacher but , course materials are not sufficient', 'given_star': 3}
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 3
# Please select the collection you want to read data from:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 2
# Filter acc to 'given_star' (greater than): 4
# {'_id': ObjectId('6659c058568bb4f8d6d27064'), 'id': '1', 'name': 'Ege Tan', 'review_message': 'good , student , hardworking student', 'given_star': 5}
# {'_id': ObjectId('6659c069568bb4f8d6d27065'), 'id': '2', 'name': 'Efe Sözer', 'review_message': 'good , student , hardworking student', 'given_star': 5}
# {'_id': ObjectId('6659c094568bb4f8d6d27066'), 'id': '3', 'name': 'Kutluhan Berke Kılıçkaya', 'review_message': 'good , student , hardworking student', 'given_star': 5}
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 3
# Please select the collection you want to read data from:
# 1 - teacher_evaluation
# 2 - student_evaluation
# Selected option: 1
# Filter acc to 'given_star' (greater than): 3
# {'_id': ObjectId('6659c2e5568bb4f8d6d27069'), 'id': '1', 'name': 'Yücel Saygın', 'review_message': 'best teacher in the world', 'given_star': 5}
# {'_id': ObjectId('6659c365568bb4f8d6d2706b'), 'id': '3', 'name': 'Hasan Ertuğrul Çınar', 'review_message': 'best TA in the world', 'given_star': 5}
#
# Please select an operation:
# 1 - Create collection
# 2 - Read all data in a collection
# 3 - Read some part of the data while filtering
# 4 - Insert data
# 5 - Delete data
# 6 - Update data
# 7 - Exit
# Your choice: 7
# Exiting...
